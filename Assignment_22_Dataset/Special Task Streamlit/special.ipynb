# %%
import pandas as pd

df = pd.read_csv("CarDetails.csv")

X = df.drop("Price", axis=1)
y = df["Price"]

X = pd.get_dummies(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (652, 285)
# (163, 285)
# (652,)
# (163,)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_pred)

r2
# Out:
# 0.651168015780349

# %%
import pandas as pd

df = pd.read_csv("CarDetails.csv")

# Drop the column named "1"
df = df.drop(columns=["1"], errors="ignore")

# Separate features and target
X = df.drop(columns=["Price"])
y = df["Price"]

# Convert text columns into dummy variables
X = pd.get_dummies(X, columns=["Name", "Company", "Fuel"], drop_first=True)

print(X.head())
# Out:
#    Year  Kms_driven  Name_Audi A4 1.8  Name_Audi A4 2.0  Name_Audi A6 2.0  \
# 0  2007       45000             False             False             False
# 1  2006          40             False             False             False
# 2  2014       28000             False             False             False
# 3  2014       36000             False             False             False
# 4  2012       41000             False             False             False
#
#    Name_Audi A8  Name_Audi Q3 2.0  Name_Audi Q5 2.0  Name_Audi Q7  \
# 0         False             False             False         False
# 1         False             False             False         False
# 2         False             False             False         False
# 3         False             False             False         False
# 4         False             False             False         False
#
#    Name_BMW 3 Series  ...  Company_Mitsubishi  Company_Nissan  \
# 0              False  ...               False           False
# 1              False  ...               False           False
# 2              False  ...               False           False
# 3              False  ...               False           False
# 4              False  ...               False           False
#
#    Company_Renault  Company_Skoda  Company_Tata  Company_Toyota  \
# 0            False          False         False           False
# 1            False          False         False           False
# 2            False          False         False           False
# 3            False          False         False           False
# 4            False          False         False           False
#
#    Company_Volkswagen  Company_Volvo  Fuel_LPG  Fuel_Petrol
# 0               False          False     False         True
# 1               False          False     False        False
# 2               False          False     False         True
# 3               False          False     False        False
# 4               False          False     False        False
#
# [5 rows x 281 columns]

# %%
import joblib

# Save trained model
joblib.dump(model, "car_price_model.pkl")
# Out:
# ['car_price_model.pkl']
