# %%
# Starting the code for the assignment / Importing main libraries
import pandas as pd  #csv Imported
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('bmw_pricing_challenge.csv')

df #Prints
# Out:
#      maker_key          model_key  mileage  engine_power registration_date  \
# 0          BMW                118   140411           100        2012-02-01
# 1          BMW                 M4    13929           317        2016-04-01
# 2          BMW                320   183297           120        2012-04-01
# 3          BMW                420   128035           135        2014-07-01
# 4          BMW                425    97097           160        2014-12-01
# ...        ...                ...      ...           ...               ...
# 4838       BMW    218 Gran Tourer    39743           110        2015-10-01
# 4839       BMW  218 Active Tourer    49832           100        2015-06-01
# 4840       BMW    218 Gran Tourer    19633           110        2015-10-01
# 4841       BMW  218 Active Tourer    27920           110        2016-04-01
# 4842       BMW                525   195840           160        2013-01-01
#
# ...

# %%
print("The first 5 rows of the dataset are:")
print(df.head())
# Out:
# The first 5 rows of the dataset are:
#   maker_key model_key  mileage  engine_power registration_date    fuel  \
# 0       BMW       118   140411           100        2012-02-01  diesel
# 1       BMW        M4    13929           317        2016-04-01  petrol
# 2       BMW       320   183297           120        2012-04-01  diesel
# 3       BMW       420   128035           135        2014-07-01  diesel
# 4       BMW       425    97097           160        2014-12-01  diesel
#
#   paint_color     car_type  feature_1  feature_2  feature_3  feature_4  \
# 0       black  convertible       True       True      False      False
# 1        grey  convertible       True       True      False      False
# 2       white  convertible      False      False      False      False
# 3         red  convertible       True       True      False      False
# 4      silver  convertible       True       True      False      False
#
#    feature_5  feature_6  feature_7  feature_8  price     sold_at
# ...

# %%
print("The shape of the DataFrame is:", df.shape)
# Out:
# The shape of the DataFrame is: (4843, 18)

# %%
print("The columns of the DataFrame are:", df.columns)
# Out:
# The columns of the DataFrame are: Index(['maker_key', 'model_key', 'mileage', 'engine_power',
#        'registration_date', 'fuel', 'paint_color', 'car_type', 'feature_1',
#        'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6',
#        'feature_7', 'feature_8', 'price', 'sold_at'],
#       dtype='object')

# %%
print("The datatypes of the DataFrame are:\n", df.dtypes)
# Out:
# The datatypes of the DataFrame are:
#  maker_key            object
# model_key            object
# mileage               int64
# engine_power          int64
# registration_date    object
# fuel                 object
# paint_color          object
# car_type             object
# feature_1              bool
# feature_2              bool
# feature_3              bool
# feature_4              bool
# feature_5              bool
# feature_6              bool
# feature_7              bool
# feature_8              bool
# price                 int64
# sold_at              object
# dtype: object

# %%
print("The null/missing values in the DataFrame are:\n", df.isnull().sum())
# Out:
# The null/missing values in the DataFrame are:
#  maker_key            0
# model_key            0
# mileage              0
# engine_power         0
# registration_date    0
# fuel                 0
# paint_color          0
# car_type             0
# feature_1            0
# feature_2            0
# feature_3            0
# feature_4            0
# feature_5            0
# feature_6            0
# feature_7            0
# feature_8            0
# price                0
# sold_at              0
# dtype: int64

# %%
print("The summary statistics for the dataset are:")
print(df.describe())
# Out:
# The summary statistics for the dataset are:
#             mileage  engine_power          price
# count  4.843000e+03    4843.00000    4843.000000
# mean   1.409628e+05     128.98823   15828.081767
# std    6.019674e+04      38.99336    9220.285684
# min   -6.400000e+01       0.00000     100.000000
# 25%    1.029135e+05     100.00000   10800.000000
# 50%    1.410800e+05     120.00000   14200.000000
# 75%    1.751955e+05     135.00000   18600.000000
# max    1.000376e+06     423.00000  178500.000000

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['car_type'], bins=20, color='red')  # no kde
plt.title("Distribution of Car Types")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='mileage', y='price', data=df, alpha=1)
plt.title("Price vs Mileage")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='fuel', y='price', data=df)
plt.title("Price Distribution by fuel Type")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='fuel', y='price', data=df)
plt.title("Average Price by Fuel Type")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df[['mileage','engine_power','price']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
df['car_type'].value_counts().plot(kind='pie')
plt.title("Car Type Distribution (Pie)")
plt.show()

# %% [markdown]
# ## Dataset Summary
#
# The dataset contains BMW car listings with the following attributes:
#
# - **maker_key** – Manufacturer name
# - **model_key** – Car model
# - **mileage** – Distance traveled by the vehicle
# - **engine_power** – Engine power rating
# - **registration_date** – Date of vehicle registration
# - **fuel** – Fuel type (e.g., Petrol, Diesel)
# - **paint_color** – Exterior color of the vehicle
# - **car_type** – Vehicle body type
# - **feature_1** to **feature_8** – Binary indicators representing various vehicle features
# - **price** – Selling price of the vehicle
# - **sold_at** – Platform or source where the vehicle was sold
#
# The dataset contains both **numerical** variables (such as *mileage*, *engine_power*, and *price*) and **categorical** variables (such as *fuel*, *car_type*, and *paint_color*).
#
# This combination makes it suitable for **descriptive statistical analysis**, **data visualization**, and **machine learning models** aimed at analyzing and predicting BMW vehicle prices.

# %% [markdown]
# ## Key Insights
#
# 1. **Fuel Type:** Most BMWs in the dataset are powered by **diesel**, followed by **petrol**, while **hybrid** and **electric** models are comparatively rare.
#
# 2. **Car Type:** **Estate**, **sedan**, and **SUV** are the most common BMW body styles, whereas **coupe**, **convertible**, and **van** models appear less frequently.
#
# 3. **Mileage vs Price:** Vehicles with **higher mileage** generally have **lower selling prices**, indicating a negative relationship between mileage and resale value.
#
# 4. **Engine Power vs Price:** Cars with **higher engine power** tend to have **higher selling prices**, suggesting that performance significantly influences market value.
#
# 5. **Paint Colors:** **Black**, **white**, and **grey** are the most common paint colors, with darker shades often showing a slightly higher resale value than other colors.

# %% [markdown]
# ## Conclusion
#
# The analysis of the BMW car dataset shows that **diesel** and **petrol** vehicles dominate the listings, with **estate**, **sedan**, and **SUV** being the most common body types. Vehicle **mileage** and **engine power** have a significant impact on the selling price, where higher mileage generally reduces price while greater engine power increases it. Additionally, **paint color** has a minor influence on resale value, with neutral shades such as **black**, **white**, and **grey** being the most popular. Overall, the dataset is well-suited for exploratory data analysis and predictive modeling of BMW vehicle prices.

# %% [markdown]
# # Dataset Information
#
# ## Dataset Name
# **BMW CARS PRICING**
#
# ## Kaggle Dataset Link
# **https://www.kaggle.com/datasets/danielkyrka/bmw-pricing-challenge**
#
#
# ## Dataset Description
# This dataset contains information about used BMW cars, including details such as model, mileage, engine power, fuel type, registration date, paint color, body type, optional features, selling price, and sales platform. It is suitable for exploratory data analysis, visualization, and predictive modeling of used car prices.
#
# ## Number of Rows and Columns
# - **Rows:** 4,843
# - **Columns:** 18
#
# ## List of Dataset Features (Columns)
# 1. maker_key
# 2. model_key
# 3. mileage
# 4. engine_power
# 5. registration_date
# 6. fuel
# 7. paint_color
# 8. car_type
# 9. feature_1
# 10. feature_2
# 11. feature_3
# 12. feature_4
# 13. feature_5
# 14. feature_6
# 15. feature_7
# 16. feature_8
# 17. price
# 18. sold_at
#
# ## Input Features (Independent Variables)
# - maker_key
# - model_key
# - mileage
# - engine_power
# - registration_date
# - fuel
# - paint_color
# - car_type
# - feature_1
# - feature_2
# - feature_3
# - feature_4
# - feature_5
# - feature_6
# - feature_7
# - feature_8
# - sold_at
#
# ## Output/Target Variable (Dependent Variable)
# - **price**
#
# ## Type of Machine Learning Problem
# **Type:** Supervised Learning
#
# **Problem Type:** Regression
#
# **Explanation:** This is a **Supervised Learning** dataset because the correct output (`price`) is already available. The model learns by using the car details, such as mileage, engine power, fuel type, and other features, to understand how the price is determined the specific machine learning problem is **Regression**..
#
# ## Conclusion
# The BMW car dataset shows that most cars use diesel or petrol and that estate, sedan, and SUV are the most common body types. The analysis also shows that cars with higher mileage usually have lower prices, while cars with more engine power tend to have higher prices. Black, white, and grey are the most common paint colors and may have a small effect on resale value. Overall, this dataset is useful for understanding BMW car prices and finding patterns in the data.
