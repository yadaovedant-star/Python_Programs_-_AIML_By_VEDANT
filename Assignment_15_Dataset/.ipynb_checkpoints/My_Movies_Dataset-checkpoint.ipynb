# %%
import pandas as pd


df = pd.read_csv(r"C:\Users\yadao\OneDrive\Desktop\ITR 2026 AIML\Assignment_15_Dataset\popular_shows_dataset.csv")

# %%
print(df.head())
# Out:
#               title  year   revenue     imdb_id  tmdb_id  trakt_id
# 0           Hoppers  2026  29000000  tt26443616  1327819   1085761
# 1  Reminders of Him  2026  18000000  tt33714084  1367642   1116720
# 2         undertone  2026   9300000  tt35892608  1480387   1213506
# 3          Scream 7  2026   8400000  tt27047903  1159559    934134
# 4              GOAT  2026   4700000  tt27613895  1297842   1057839

# %%
print("Last 5 rows:\n", df.tail(), "\n")
# Out:
# Last 5 rows:
#                                                   title  year  revenue  \
# 995                                         The Bride!  2026  2100000
# 996                            Kiki's Delivery Service  1989  1700000
# 997                                "Wuthering Heights"  2026  1700000
# 998  Teenage Mutant Ninja Turtles II: The Secret of...  1991  1500000
# 999                                          Crime 101  2026  1100000
#
#         imdb_id  tmdb_id  trakt_id
# 995  tt30851137  1159831    934595
# 996   tt0097814    16859     10314
# 997  tt32897959  1316092   1077273
# 998   tt0103060     1497       991
# 999  tt32430579  1171145    944042

# %%
print("Shape (rows, columns):", df.shape, "\n")
# Out:
# Shape (rows, columns): (1000, 6)

# %%
print("Column names:\n", df.columns, "\n")
# Out:
# Column names:
#  Index(['title', 'year', 'revenue', 'imdb_id', 'tmdb_id', 'trakt_id'], dtype='str')

# %%
print("Info:\n") 
print(df.info())
# Out:
# Info:
#
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1000 non-null   str
#  1   year      1000 non-null   int64
#  2   revenue   1000 non-null   int64
#  3   imdb_id   1000 non-null   str
#  4   tmdb_id   1000 non-null   int64
#  5   trakt_id  1000 non-null   int64
# dtypes: int64(4), str(2)
# memory usage: 47.0 KB
# None

# %%
print("\nSummary stats:\n", df.describe(), "\n")
# Out:
# Summary stats:
#                year       revenue       tmdb_id      trakt_id
# count  1000.000000  1.000000e+03  1.000000e+03  1.000000e+03
# mean   2018.800000  7.750000e+06  1.029867e+06  8.375175e+05
# std      14.414152  8.705877e+06  5.195836e+05  4.246083e+05
# min    1989.000000  1.100000e+06  1.497000e+03  9.910000e+02
# 25%    2026.000000  1.700000e+06  1.159559e+06  9.341340e+05
# 50%    2026.000000  3.400000e+06  1.234494e+06  1.000940e+06
# 75%    2026.000000  9.300000e+06  1.327819e+06  1.085761e+06
# max    2026.000000  2.900000e+07  1.480387e+06  1.213506e+06

# %%
print("Data types:\n", df.dtypes, "\n")
# Out:
# Data types:
#  title         str
# year        int64
# revenue     int64
# imdb_id       str
# tmdb_id     int64
# trakt_id    int64
# dtype: object

# %%
print("Missing values:\n", df.isnull().sum(), "\n")
# Out:
# Missing values:
#  title       0
# year        0
# revenue     0
# imdb_id     0
# tmdb_id     0
# trakt_id    0
# dtype: int64

# %%
print("Unique values:\n", df.nunique(), "\n")
# Out:
# Unique values:
#  title       10
# year         3
# revenue      9
# imdb_id     10
# tmdb_id     10
# trakt_id    10
# dtype: int64

# %%
print("Random sample:\n", df.sample(5), "\n")
# Out:
# Random sample:
#                                                   title  year  revenue  \
# 214                                               GOAT  2026  4700000
# 828  Teenage Mutant Ninja Turtles II: The Secret of...  1991  1500000
# 283                                           Scream 7  2026  8400000
# 925                                         The Bride!  2026  2100000
# 486                            Kiki's Delivery Service  1989  1700000
#
#         imdb_id  tmdb_id  trakt_id
# 214  tt27613895  1297842   1057839
# 828   tt0103060     1497       991
# 283  tt27047903  1159559    934134
# 925  tt30851137  1159831    934595
# 486   tt0097814    16859     10314

# %%
print("Value counts for 'title':\n", df["title"].value_counts(), "\n")
# Out:
# Value counts for 'title':
#  title
# Hoppers                                                    100
# Reminders of Him                                           100
# undertone                                                  100
# Scream 7                                                   100
# GOAT                                                       100
# The Bride!                                                 100
# Kiki's Delivery Service                                    100
# "Wuthering Heights"                                        100
# Teenage Mutant Ninja Turtles II: The Secret of the Ooze    100
# Crime 101                                                  100
# Name: count, dtype: int64

# %%
print("Value counts for 'revenue':\n", df["revenue"].value_counts(), "\n")
# Out:
# Value counts for 'revenue':
#  revenue
# 1700000     200
# 29000000    100
# 18000000    100
# 9300000     100
# 8400000     100
# 4700000     100
# 2100000     100
# 1500000     100
# 1100000     100
# Name: count, dtype: int64
