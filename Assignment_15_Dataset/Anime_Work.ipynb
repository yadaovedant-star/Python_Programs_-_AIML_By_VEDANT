# %%
import pandas as pd


df = pd.read_csv(r"C:\Users\yadao\OneDrive\Desktop\ITR 2026 AIML\Assignment_15_Dataset\Anime.csv")

# %%
print(df.head())
# Out:
#    Rank                                               Name  \
# 0     1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1     2                     Fruits Basket the Final Season
# 2     3                                    Mo Dao Zu Shi 3
# 3     4                   Fullmetal Alchemist: Brotherhood
# 4     5                Attack on Titan 3rd Season: Part II
#
#                                      Japanese_name   Type  Episodes  \
# 0                    Kimetsu no Yaiba: Yuukaku-hen  TV          NaN
# 1                          Fruits Basket the Final  TV         13.0
# 2                       The Founder of Diabolism 3  Web        12.0
# 3   Hagane no Renkinjutsushi: Full Metal Alchemist  TV         64.0
# 4             Shingeki no Kyojin Season 3: Part II  TV         10.0
#
#               Studio Release_season  \
# 0           ufotable          Fall
# 1  TMS Entertainment         Spring
# 2   B.C MAY PICTURES            NaN
# 3              Bones         Spring
# ...

# %%
print("Last 5 rows:\n", df.tail(), "\n")
# Out:
# Last 5 rows:
#          Rank                                               Name Japanese_name  \
# 18490  18491  Qin Shi Mingyue: Canghai Hengliu Xiaomeng Spec...           NaN
# 18491  18492                      Yi Tang Juchang: Sanguo Yanyi           NaN
# 18492  18493          Fenghuang Ji Xiang Yu Qingming Shanghe Tu           NaN
# 18493  18494                      Chengshi Jiyi Wo Men de Jieri           NaN
# 18494  18495  Heisei Inu Monogatari Bow: Genshi Inu Monogata...           NaN
#
#         Type  Episodes                        Studio Release_season  \
# 18490  Web         2.0  Sparkly Key Animation Studio            NaN
# 18491  TV        108.0                           NaN            NaN
# 18492  TV         13.0                           NaN            NaN
# 18493  TV          NaN                           NaN            NaN
# 18494  Movie       NaN              Nippon Animation            NaN
#
#                                                     Tags  Rating  \
# ...

# %%
print("Shape of the dataset:\n", df.shape, "\n")
# Out:
# Shape of the dataset:
#  (18495, 17)

# %%
print("Column names:\n", df.columns, "\n")
# Out:
# Column names:
#  Index(['Rank', 'Name', 'Japanese_name', 'Type', 'Episodes', 'Studio',
#        'Release_season', 'Tags', 'Rating', 'Release_year', 'End_year',
#        'Description', 'Content_Warning', 'Related_Mange', 'Related_anime',
#        'Voice_actors', 'staff'],
#       dtype='str')

# %%
print("Info:\n") 
print(df.info())
# Out:
# Info:
#
# <class 'pandas.DataFrame'>
# RangeIndex: 18495 entries, 0 to 18494
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             18495 non-null  int64
#  1   Name             18495 non-null  str
#  2   Japanese_name    7938 non-null   str
#  3   Type             18495 non-null  str
#  4   Episodes         9501 non-null   float64
#  5   Studio           12018 non-null  str
#  6   Release_season   4116 non-null   str
#  7   Tags             18095 non-null  str
#  8   Rating           15364 non-null  float64
#  9   Release_year     18112 non-null  float64
#  10  End_year         2854 non-null   float64
#  11  Description      18491 non-null  str
#  12  Content_Warning  1840 non-null   str
#  13  Related_Mange    7627 non-null   str
#  14  Related_anime    10063 non-null  str
#  15  Voice_actors     15309 non-null  str
#  16  staff            13005 non-null  str
# ...

# %%
print("\nSummary stats:\n", df.describe(), "\n")
# Out:
# Summary stats:
#                Rank     Episodes        Rating  Release_year     End_year
# count  18495.00000  9501.000000  15364.000000  18112.000000  2854.000000
# mean    9248.00000    20.920850      3.355133   2006.520318  2004.256132
# std     5339.19095    37.990858      0.400624     15.189537    13.257484
# min        1.00000     1.000000      0.960000   1907.000000  1962.000000
# 25%     4624.50000     2.000000      3.130000   2001.000000  1996.000000
# 50%     9248.00000    12.000000      3.360000   2012.000000  2007.000000
# 75%    13871.50000    26.000000      3.590000   2017.000000  2015.000000
# max    18495.00000   800.000000      4.600000   2023.000000  2022.000000

# %%
print("Data types:\n", df.dtypes, "\n")
# Out:
# Data types:
#  Rank                 int64
# Name                   str
# Japanese_name          str
# Type                   str
# Episodes           float64
# Studio                 str
# Release_season         str
# Tags                   str
# Rating             float64
# Release_year       float64
# End_year           float64
# Description            str
# Content_Warning        str
# Related_Mange          str
# Related_anime          str
# Voice_actors           str
# staff                  str
# dtype: object

# %%
print("Missing values:\n", df.isnull().sum(), "\n")
# Out:
# Missing values:
#  Rank                   0
# Name                   0
# Japanese_name      10557
# Type                   0
# Episodes            8994
# Studio              6477
# Release_season     14379
# Tags                 400
# Rating              3131
# Release_year         383
# End_year           15641
# Description            4
# Content_Warning    16655
# Related_Mange      10868
# Related_anime       8432
# Voice_actors        3186
# staff               5490
# dtype: int64

# %%
print("Unique values:\n", df.nunique(), "\n")
# Out:
# Unique values:
#  Rank               18495
# Name               18443
# Japanese_name       7902
# Type                   8
# Episodes             205
# Studio               745
# Release_season         4
# Tags               11799
# Rating               289
# Release_year         103
# End_year              60
# Description        10012
# Content_Warning      208
# Related_Mange       4151
# Related_anime       9451
# Voice_actors       13615
# staff              10559
# dtype: int64

# %%
print("Random sample:\n", df.sample(10), "\n")
# Out:
# Random sample:
#          Rank                                               Name  \
# 1393    1394                                                  K
# 12705  12706                                            Akuemon
# 16073  16074                                Hu Lu Xiao Jin Gang
# 14668  14669                 Skirt no Naka wa Kedamono Deshita.
# 10027  10028                                 Neru: Dappou Rokku
# 6813    6814                               Bakutsuri Bar Hunter
# 6167    6168                                So, I Can't Play H!
# 9717    9718                                     Karada Sagashi
# 3260    3261  Crayon Shin-chan Movie 18: Chou Jikuu! Arashi ...
# 17824  17825                                        Chibinacs 3
#
#                         Japanese_name   Type  Episodes             Studio  \
# 1393                        K Project  TV         13.0            GoHands
# 12705                             NaN  OVA         1.0                NaN
# ...

# %%
print("Value counts for 'Name':\n", df["Name"].value_counts(), "\n")
# Out:
# Value counts for 'Name':
#  Name
# [email protected]                                       4
# Genki! Genki! Nontan: Spoon Tan Tan Tan                 2
# Bai Gui Youeryuan 3rd Season                            2
# Mahjong Hishouden: Naki no Ryuu (1991)                  2
# Turning Mecard W Movie: Black Mirror ui Buhwal          2
#                                                        ..
# Qin Shi Mingyue: Canghai Hengliu Xiaomeng Specials      1
# Yi Tang Juchang: Sanguo Yanyi                           1
# Fenghuang Ji Xiang Yu Qingming Shanghe Tu               1
# Chengshi Jiyi Wo Men de Jieri                           1
# Heisei Inu Monogatari Bow: Genshi Inu Monogatari Bow    1
# Name: count, Length: 18443, dtype: int64

# %%
print("Value counts for 'Type':\n", df["Type"].value_counts(), "\n")
# Out:
# Value counts for 'Type':
#  Type
# TV       5446
# Movie    3577
# Web      2488
# OVA      2235
# Music    2165
# Other     990
# DVD S     911
# TV Sp     683
# Name: count, dtype: int64
